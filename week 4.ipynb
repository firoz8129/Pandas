# %%
import pandas as pd

data={
    "name":["firoz",'razi','ashi'],
    'age':[10,20,30]
}
df=pd.DataFrame(data)
print(df)
# Out:
#     name  age
# 0  firoz   10
# 1   razi   20
# 2   ashi   30

# %%
a=df[df['age']>20]
print(a)
# Out:
#    name  age
# 2  ashi   30

# %%
s=df.iloc[0:2]
print(s)
# Out:
#     name  age
# 0  firoz   10
# 1   razi   20
