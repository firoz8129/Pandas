# %%
import pandas as pd
import numpy as np

data={
    'name':['aaa','bbb','ccc','ddd'],
    "age":[10,20,30,40]
}
df=pd.DataFrame(data)
print(df)
print(df.iloc[0:1])
# Out:
#   name  age
# 0  aaa   10
# 1  bbb   20
# 2  ccc   30
# 3  ddd   40
#   name  age
# 0  aaa   10

# %%
data={
    'name':['aaa','bbb','ccc','ddd','eee'],
    "age":[10,20,90,30,40]
}
df=pd.DataFrame(data)
print(df.sort_values(['age'],ascending=False))
# Out:
#   name  age
# 2  ccc   90
# 4  eee   40
# 3  ddd   30
# 1  bbb   20
# 0  aaa   10

# %%
import pandas as pd
import numpy as np
data={
    'name':['aaa','bbb','ccc','ddd','eee'],
    "age":[10,20,30,40,None]
}
df=pd.DataFrame(data)
#s=df['age']=df['age'].fillna(df['age'].mean())
#print(s)
#df1=df.fillna(df['age'].mean())
#print(df1)
print(df.nlargest(3,['age']))

print(df.nsmallest(3,['age']))
# Out:
#   name   age
# 3  ddd  40.0
# 2  ccc  30.0
# 1  bbb  20.0
#   name   age
# 0  aaa  10.0
# 1  bbb  20.0
# 2  ccc  30.0

# %%
a=df['age'].mean()
print(df.fillna(a))
# Out:
#   name   age
# 0  aaa  10.0
# 1  bbb  20.0
# 2  ccc  30.0
# 3  ddd  40.0
# 4  eee  25.0

# %%
data = {
    'Name': ['Firoz', 'Firoz', 'Uvais', 'Uvais'],
    'Subject': ['Math', 'English', 'Math', 'English'],
    'Marks': [85, 90, 80, 88]
}
df=pd.DataFrame(data)
print(df)

pivot_df=df.pivot(index='Name',columns='Subject',values='Marks')
print(pivot_df)
# Out:
#     Name  Subject  Marks
# 0  Firoz     Math     85
# 1  Firoz  English     90
# 2  Uvais     Math     80
# 3  Uvais  English     88
# Subject  English  Math
# Name
# Firoz         90    85
# Uvais         88    80
